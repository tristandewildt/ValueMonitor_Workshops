# %% [markdown]
# # ValueMonitor - Create your own topic model

# %% [markdown]
# This page is a visualisation of the ValueMonitor prototype. In case you would like to use the notebook, click on the icon ‘**Run in Google Colab**’ hereunder:

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/tristandewildt/ValueMonitor_Workshops/blob/main/ValueMonitor_Workshop_create_own_model.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/tristandewildt/ValueMonitor_Workshops/blob/main/ValueMonitor_Workshop_create_own_model.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# ## Table of content:
# * [1. Import dataset and packages](#import_dataset_and_packages)
# * [2. Creating the topic model](#creating_the_topic_model)
# * [3. Verifying the topic model](#verifying_the_topic_model)
# * [4. Values in different realms](#values_in_different_realms)
# * [5. Values over time](#values_over_time)
# * [6. Gap assessment](#gap_assessment)

# %% [markdown]
# ## 1. Import dataset and packages  <a name="import_dataset_and_packages"></a>

# %% [markdown]
# ### 1.1. Import packages

# %% [markdown]
# In this step, the relavant python packages are imported

# %%
pip install pandas==1.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas==1.4.1 in /usr/local/lib/python3.9/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.1) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.1) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas==1.4.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas==1.4.1) (1.15.0)

# %%
''' Packages'''

# !pip install corextopic
# !pip install joblib
# !pip install tabulate
# !pip install simple_colors
# !pip install ipyfilechooser
# !pip install colorama
# !pip install umap_learn

import os, sys, importlib
import pandas as pd
import ipywidgets as widgets
from ipywidgets import interact, interact_manual, Button
import pickle
from ipyfilechooser import FileChooser
from tkinter import Tk, filedialog
from IPython.display import clear_output, display
from google.colab import files
import nltk
import io

nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('vader_lexicon')

''' Source code'''

user = "tristandewildt"
repo = "ValueMonitor_Workshops"
src_dir = "code"
pyfile_1 = "make_topic_model.py"
pyfile_2 = "create_visualisation.py"
token = "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"

if os.path.isdir(repo):
  # !rm -rf {repo}

# !git clone https://{token}@github.com/{user}/{repo}.git

from ValueMonitor_Workshops.code.make_topic_model import *
from ValueMonitor_Workshops.code.create_visualisation import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: corextopic in /usr/local/lib/python3.9/dist-packages (1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (0.8.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simple_colors in /usr/local/lib/python3.9/dist-packages (0.1.5)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (from ipyfilechooser) (7.7.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ipyfilechooser) (7.9.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ipyfilechooser) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ipyfilechooser) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ipyfilechooser) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ipyfilechooser) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets->ipyfilechooser) (3.6.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (6.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (2.6.1)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets->ipyfilechooser) (2.0.10)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (6.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets->ipyfilechooser) (0.8.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (6.5.4)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.16.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (5.7.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (1.8.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (5.2.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (23.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.17.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->ipyfilechooser) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->ipyfilechooser) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets->ipyfilechooser) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (3.1.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (4.9.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.8.4)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (1.2.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (23.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (4.6.3)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.7.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (2.16.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (22.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->ipyfilechooser) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (0.4.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: umap_learn in /usr/local/lib/python3.9/dist-packages (0.5.3)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/dist-packages (from umap_learn) (0.5.8)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from umap_learn) (1.22.4)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap_learn) (0.56.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from umap_learn) (4.65.0)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/dist-packages (from umap_learn) (1.2.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from umap_learn) (1.10.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap_learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap_learn) (57.4.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/dist-packages (from pynndescent>=0.5->umap_learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22->umap_learn) (3.1.0)
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Cloning into 'ValueMonitor_Workshops'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 203 (delta 88), reused 71 (delta 44), pack-reused 53
# Receiving objects: 100% (203/203), 3.16 MiB | 4.43 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %% [markdown]
# ##1.2. Import dataset

# %% [markdown]
# **Dataset 1: digital technologies**
#
# This is a dataset used for a report for STOA and the  European Parliament: 'Ethical and societal
# challenges of the approaching technological storm' (https://www.europarl.europa.eu/RegData/etudes/STUD/2022/729543/EPRS_STU(2022)729543_EN.pdf)
#
# The dataset focus on  the following digital technologies: 5G/6G, AI, Robotics, Internet of Things, Augmented Reality, Virtual Reality, Blockchain, Bio-nanotechnology.
#
# We have created topics for the following values: Justice and Fairness, Privacy, Cyber-security, Environmental Sustainability, Transparency, Accountability, Autonomy, Democracy, Reliability, Trust, Well-being, Inclusivness
#
# The dataset include four types of documents:
# *   Technological and scientific research (scientific articles from journal with an engineering background)
# *   Ethical research (scientific articles from journal on ethics)
# *   News media (newspaper articles on digital technologies)
# *   EU regulation on digital technologies

# %%
''' Digital technologies'''

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=14W1UddxBOmJZC76NhmECqYy1wzULillW' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=14W1UddxBOmJZC76NhmECqYy1wzULillW" -O dataset_digital_technologies && rm -rf /tmp/cookies.txt
with open('dataset_digital_technologies', "rb") as fh:
    df = pickle.load(fh)
# Out:
# --2023-03-09 15:57:30--  https://docs.google.com/uc?export=download&confirm=&id=14W1UddxBOmJZC76NhmECqYy1wzULillW
# Resolving docs.google.com (docs.google.com)... 173.194.216.100, 173.194.216.102, 173.194.216.139, ...
# Connecting to docs.google.com (docs.google.com)|173.194.216.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kkbaa68lvgp215l8rhjke30kcn5hh5tn/1678377450000/12635936161789443610/*/14W1UddxBOmJZC76NhmECqYy1wzULillW?e=download&uuid=26686309-2add-4f57-adf9-9b15397275c9 [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-09 15:57:31--  https://doc-08-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kkbaa68lvgp215l8rhjke30kcn5hh5tn/1678377450000/12635936161789443610/*/14W1UddxBOmJZC76NhmECqYy1wzULillW?e=download&uuid=26686309-2add-4f57-adf9-9b15397275c9
# Resolving doc-08-2c-docs.googleusercontent.com (doc-08-2c-docs.googleusercontent.com)... 74.125.196.132, 2607:f8b0:400c:c36::84
# Connecting to doc-08-2c-docs.googleusercontent.com (doc-08-2c-docs.googleusercontent.com)|74.125.196.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45758949 (44M) [application/octet-stream]
# Saving to: ‘dataset_digital_technologies’
#
# dataset_digital_tec 100%[===================>]  43.64M   148MB/s    in 0.3s
#
# 2023-03-09 15:57:32 (148 MB/s) - ‘dataset_digital_technologies’ saved [45758949/45758949]

# %% [markdown]
# **Dataset 2: energy transition**
#
# This is a dataset made compare values addressed by different scientific fields on the energy transition.
#
# The dataset has been obtained by downloading scientific articles from scopus mentionning words 'energy transition' and 'global warming'.
#
# We have created topics for the following values: Environmental Sustainability, Safety, Economic Viability, Efficiency, Affordability.
#
# The dataset include articles from the following scientific fields:
#
# *   Environmental biology
# *   Environmental economics
# *   Environmental psychology
# *   Environmental sustainability
# *   Philosophy of sustainability
# *   Sustainable building
# *   Sustainable finance
# *   Sustainable mobility

# %%
''' Energy Transition Literature'''

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=14jvSWbvh7z_evqki0Gm05_xJM6G-UqC3' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=14jvSWbvh7z_evqki0Gm05_xJM6G-UqC3" -O dataset_energy_transition_literature && rm -rf /tmp/cookies.txt
with open('dataset_energy_transition_literature', "rb") as fh:
    df = pickle.load(fh)
# Out:
# --2023-03-08 13:46:24--  https://docs.google.com/uc?export=download&confirm=&id=14jvSWbvh7z_evqki0Gm05_xJM6G-UqC3
# Resolving docs.google.com (docs.google.com)... 142.251.31.100, 142.251.31.113, 142.251.31.102, ...
# Connecting to docs.google.com (docs.google.com)|142.251.31.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gd5at1lde6b2q3fibgt2hhvtomessd3k/1678283175000/12635936161789443610/*/14jvSWbvh7z_evqki0Gm05_xJM6G-UqC3?e=download&uuid=11536727-8a19-44eb-aba4-38ef463c8481 [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-08 13:46:26--  https://doc-04-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/gd5at1lde6b2q3fibgt2hhvtomessd3k/1678283175000/12635936161789443610/*/14jvSWbvh7z_evqki0Gm05_xJM6G-UqC3?e=download&uuid=11536727-8a19-44eb-aba4-38ef463c8481
# Resolving doc-04-2c-docs.googleusercontent.com (doc-04-2c-docs.googleusercontent.com)... 108.177.96.132, 2a00:1450:4013:c06::84
# Connecting to doc-04-2c-docs.googleusercontent.com (doc-04-2c-docs.googleusercontent.com)|108.177.96.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88805423 (85M) [application/octet-stream]
# Saving to: ‘dataset_energy_transition_literature’
#
# dataset_energy_tran 100%[===================>]  84.69M   200MB/s    in 0.4s
#
# 2023-03-08 13:46:26 (200 MB/s) - ‘dataset_energy_transition_literature’ saved [88805423/88805423]

# %% [markdown]
# **Dataset 3: hydrogen technology**
#
# This is a dataset made for an ongoing paper on value change in hydrogen technology.
#
# We have created topics for the following values: Environmental Sustainability, Safety, Economic Viability, Efficiency, Affordability.
#
# The dataset include two types of documents:
# *   Technological and scientific research (scientific articles from journal with an engineering background)
# *   News media (newspaper articles on hydrogen technology)

# %%
''' Hydrogen technology'''

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=14lZyvRFqbkDp8w6xFojjUWUNnVvSduUF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=14lZyvRFqbkDp8w6xFojjUWUNnVvSduUF" -O dataset_hydrogen_technology && rm -rf /tmp/cookies.txt
with open('dataset_hydrogen_technology', "rb") as fh:
    df = pickle.load(fh)
# Out:
# --2023-03-09 15:51:57--  https://docs.google.com/uc?export=download&confirm=t&id=14lZyvRFqbkDp8w6xFojjUWUNnVvSduUF
# Resolving docs.google.com (docs.google.com)... 173.194.216.138, 173.194.216.100, 173.194.216.101, ...
# Connecting to docs.google.com (docs.google.com)|173.194.216.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-10-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/e2d5hjqgt3ts2es67vft09q10sfat9iq/1678377075000/12635936161789443610/*/14lZyvRFqbkDp8w6xFojjUWUNnVvSduUF?e=download&uuid=734a5f43-4bd5-4304-ad50-65199756b01f [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-09 15:51:57--  https://doc-10-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/e2d5hjqgt3ts2es67vft09q10sfat9iq/1678377075000/12635936161789443610/*/14lZyvRFqbkDp8w6xFojjUWUNnVvSduUF?e=download&uuid=734a5f43-4bd5-4304-ad50-65199756b01f
# Resolving doc-10-2c-docs.googleusercontent.com (doc-10-2c-docs.googleusercontent.com)... 142.251.107.132, 2607:f8b0:400c:c32::84
# Connecting to doc-10-2c-docs.googleusercontent.com (doc-10-2c-docs.googleusercontent.com)|142.251.107.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 466874515 (445M) [application/octet-stream]
# Saving to: ‘dataset_hydrogen_technology’
#
# dataset_hydrogen_te 100%[===================>] 445.25M  92.8MB/s    in 5.6s
#
# 2023-03-09 15:52:03 (79.0 MB/s) - ‘dataset_hydrogen_technology’ saved [466874515/466874515]

# %% [markdown]
# **Dataset 4: Water reuse**
#
# This is a dataset on water reuse / recycling.
#
# The dataset include three types of documents:
# *   Scientific articles from scopus (Broad query: "Water Reuse"  OR  "Water Recycling")
# *   Scientific articles from scopus (Detailed query: "Water Reuse"  OR  "Water Recycling"  OR  "Recycled Water "  OR  "Direct Potable Reuse" )  AND  ( potable  OR  drinking )  AND NOT  nonpotable)
# *   News media (Broad query: "Water Reuse"  OR  "Water Recycling")

# %%
''' Water reuse '''

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=127NHadbD0AySu3W2BB14R69SltrVScIE' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=127NHadbD0AySu3W2BB14R69SltrVScIE" -O dataset_water_reuse && rm -rf /tmp/cookies.txt
with open('dataset_water_reuse', "rb") as fh:
    df = pickle.load(fh)
# Out:
# --2023-03-08 15:22:14--  https://docs.google.com/uc?export=download&confirm=t&id=127NHadbD0AySu3W2BB14R69SltrVScIE
# Resolving docs.google.com (docs.google.com)... 172.217.218.102, 172.217.218.101, 172.217.218.113, ...
# Connecting to docs.google.com (docs.google.com)|172.217.218.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pg81mr71ij5snd9plfs3cm9konq64s6d/1678288875000/12635936161789443610/*/127NHadbD0AySu3W2BB14R69SltrVScIE?e=download&uuid=530862a0-3bb3-4e8a-bd3a-d11ef3faceb5 [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-08 15:22:15--  https://doc-0c-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/pg81mr71ij5snd9plfs3cm9konq64s6d/1678288875000/12635936161789443610/*/127NHadbD0AySu3W2BB14R69SltrVScIE?e=download&uuid=530862a0-3bb3-4e8a-bd3a-d11ef3faceb5
# Resolving doc-0c-2c-docs.googleusercontent.com (doc-0c-2c-docs.googleusercontent.com)... 173.194.79.132, 2a00:1450:4013:c05::84
# Connecting to doc-0c-2c-docs.googleusercontent.com (doc-0c-2c-docs.googleusercontent.com)|173.194.79.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 542104706 (517M) [application/octet-stream]
# Saving to: ‘dataset_water_reuse’
#
# dataset_water_reuse 100%[===================>] 516.99M   156MB/s    in 3.3s
#
# 2023-03-08 15:22:18 (156 MB/s) - ‘dataset_water_reuse’ saved [542104706/542104706]

# %% [markdown]
# **Dataset 5: Nuclear energy**
#
# The dataset include two types of documents:
# *   News paper articles extracted using the keyword 'nuclear energy' and 'nuclear power'
# *   Scientific articles from scopus extracted using the keyword 'nuclear energy' and 'nuclear power'

# %%
''' Nuclear energy '''

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=12C2j8xpeVTJhNdUqUVMCV1laAKQQXNqh' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=12C2j8xpeVTJhNdUqUVMCV1laAKQQXNqh" -O dataset_nuclear_energy && rm -rf /tmp/cookies.txt
with open('dataset_nuclear_energy', "rb") as fh:
    df = pickle.load(fh)
# Out:
# --2023-03-08 16:32:22--  https://docs.google.com/uc?export=download&confirm=t&id=12C2j8xpeVTJhNdUqUVMCV1laAKQQXNqh
# Resolving docs.google.com (docs.google.com)... 108.177.119.102, 108.177.119.138, 108.177.119.139, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l68jsig50nhraldcpsevmak0eofj112g/1678293075000/12635936161789443610/*/12C2j8xpeVTJhNdUqUVMCV1laAKQQXNqh?e=download&uuid=f15cd477-9e7d-4c2f-bf6f-56af1bf85c59 [following]
# Warning: wildcards not supported in HTTP.
# --2023-03-08 16:32:23--  https://doc-0s-2c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/l68jsig50nhraldcpsevmak0eofj112g/1678293075000/12635936161789443610/*/12C2j8xpeVTJhNdUqUVMCV1laAKQQXNqh?e=download&uuid=f15cd477-9e7d-4c2f-bf6f-56af1bf85c59
# Resolving doc-0s-2c-docs.googleusercontent.com (doc-0s-2c-docs.googleusercontent.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# Connecting to doc-0s-2c-docs.googleusercontent.com (doc-0s-2c-docs.googleusercontent.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1041589323 (993M) [application/octet-stream]
# Saving to: ‘dataset_nuclear_energy’
#
# dataset_nuclear_ene 100%[===================>] 993.34M   173MB/s    in 6.8s
#
# 2023-03-08 16:32:30 (146 MB/s) - ‘dataset_nuclear_energy’ saved [1041589323/1041589323]

# %% [markdown]
# ##2. Creating the topic model

# %% [markdown]
# In this step, we create a topic model in which some of the topics refer to values. The creation of topics that reflect values is done by means of so-called 'anchor' words. These words guide the algorithm in the creation of topics that reflect values.
#
# Anchor words are typically words that people use to refer to (the idea of) a value, such as synonyms. After adding some anchor words and running the model, the algorithm will automatically pick up other words that refer to the value. This is because the algorithm has observed that these words are often mentionned in the same documents as the anchor words.
#
# Finding the right anchor words is typically an iterative process, by observing the new topic model created by the algorithm. Some anchor words need to be added to ensure that some aspect of the value are not left behind (to be placed in *dict_anchor_words* in the cell below). Other words need to be removed since they do not refer to the value (in *list_rejected_words* in the cell below).
#
# We have prefilled an number of anchor words for each value.

# %%
dict_anchor_words = {
"Justice and Fairness" : ["justice", "fairness", "fair", "equality", "unfair"],
"Privacy" : ["privacy", "personal data", "personal sphere", "data privacy", "privacy protection", "privacy concerns", 
             "confidentiality"],
"Cyber-security" : ["cyber", "security", "cybersecurity", "malicious", "attacks"],
"Environmnental Sustainability" : ["sustainability", "sustainable", "renewable", "durable", "durability",
                                  "sustainable development", "environmental"],
"Transparency" : ["transparency", "transparent", "transparently", "explainability", "interpretability", "explainable",
                 "opaque", "interpretable"],
"Accountability" : ["accountable", "accountability", "accountable", "traceability", "traceable"],
"Autonomy" : ["autonomy", "self-determination", "autonomy human", "personal autonomy"], 
"Democracy" : ["democracy", "democratic", "human rights", "freedom speech", "equal representation",
              "political"], 
"Reliability" : ["reliability", "reliable", "robustness", "robust", "predictability"],
"Trust" : ["trust", "trustworthy", "trustworthiness", "confidence", "honesty"],
"Well-being" : ["well being", "well-being", "wellbeing", "quality life",
               "good life", "qol", "life satisfaction", "welfare"],
"Inclusiveness" : ["inclusiveness", "inclusive", "inclusivity", "discrimination", "diversity"]
}

list_rejected_words = ["iop", "iop publishing", "publishing ltd", "publishing", "licence iop",
                       "mdpi basel", "basel switzerland", "mdpi", "basel", "licensee mdpi", "licensee", "authors licensee", 
                       "switzerland", "authors", "publishing limited", "emerald", "emerald publishing", ]

list_anchor_words_other_topics = [
   #     ["internet of things", "iot", "internet things", "iot devices", "things iot"],
   #     ["artificial intelligence", "ai", "artificial"],
]

# %%
number_of_topics_to_find = 50
number_of_documents_in_analysis = 1000

number_of_words_per_topic = 10

'''--------------------------------------------------------------------------''' 

model_and_vectorized_data = make_anchored_topic_model(df, number_of_topics_to_find, min(number_of_documents_in_analysis, len(df)), dict_anchor_words, list_anchor_words_other_topics, list_rejected_words)
topics = report_topics(model_and_vectorized_data[0], dict_anchor_words,number_of_words_per_topic)
df_with_topics = create_df_with_topics(df, model_and_vectorized_data[0], model_and_vectorized_data[1], number_of_topics_to_find)
topics_weights = report_topics_words_and_weights(model_and_vectorized_data[0], dict_anchor_words, number_of_words_per_topic)
# Out:
# Topic #0 (Justice and Fairness): justice, fair, office, post, court, politics, sure, today, look, california
# Topic #1 (Privacy): privacy, personal data, data privacy, privacy concerns, data, surveillance, data protection, security privacy, protection, consent
# Topic #2 (Cyber-security): subsidiary news, hill street, contents site, corp subsidiary, fax contents, news communications, nw, nw suite, publishing corp, dc 202
# Topic #3 (Environmnental Sustainability): environmental, sustainable, iot, internet things, sustainability, things iot, renewable, sustainable development, smart, management
# Topic #4 (Transparency): transparency, transparent, silicon valley, silicon, valley, opaque, explainable, explainability, practices, regulation
# Topic #5 (Accountability): accountability, accountable, enforcement, law enforcement, groups, crime, agencies, nbc, interference, testimony
# Topic #6 (Autonomy): autonomy, tear gas, kong police, carrie lam, demonstrators, tear, lam, country systems, protesters hong, extradition bill
# Topic #7 (Democracy): political, democracy, democratic, election, human rights, campaign, elections, voters, anti, vote
# Topic #8 (Reliability): learning, machine, machine learning, reliability, robust, algorithm, deep learning, neural, robustness, algorithms
# Topic #9 (Trust): much, course, few, right, first, point, anything, little, person, someone
# Topic #10 (Well-being): welfare, well being, care, health, well, health care, class, patients, medical, being
# Topic #11 (Inclusiveness): everyone, real, home, book, sense, only, diversity, word, young, mind
# Topic #12: last, year, york, new york, government, country, week, news, years, publishing
# Topic #13: foreign, china, trade, leader, hong, hong kong, kong, protests, xi, beijing
# Topic #14: business, money, market, investors, capital, businesses, firm, investment, founder, fund
# Topic #15: american, america, report, americans, private, nation, issue, major, laws, policies
# Topic #16: service, favorite, jeff, blog, numbers, drug, specific, potential, internal, bezos
# Topic #17: lives, questions, likely, decisions, problems, think, negative, responsible, positive, language
# Topic #18: public, force, program, risk, safety, miles, climate, conference, system, residents
# Topic #19: company, tech, companies, tech companies, industry, employees, products, technology, ceo, software
# Topic #20: economic, european, west, central, europe, step, region, sign, western, annual
# Topic #21: something, lot, kind, ve, re, bad, everything, isn, good, work
# Topic #22: google, app, users, online, apple, web, video, digital, facebook google, advertising
# Topic #23: chinese, reuters, monday, reporting, friday, statement, additional, chinese government, tuesday, additional reporting
# Topic #24: trump, president, house, white house, administration, washington, united, states, united states, white
# Topic #25: former, state, bill, john, morning, civil, meeting, wednesday, opposition, activists
# Topic #26: product, start, startups, co, price, founders, startup, brands, co founder, business model
# Topic #27: facebook, social media, media, social, zuckerberg, twitter, content, mark, platforms, platform
# Topic #28: old, days, story, school, back, children, full, phone, summer, call
# Topic #29: so, so called, called, important, sexual, dark, order, audience, beliefs, abuse
# Topic #30: university, computer, professor, science, humans, stanford, computer science, human, berkeley, machines
# Topic #31: answer, editor, son, decades, late, age, fear, century, feel, reality
# Topic #32: times, many, party, power, line, movement, up, email, page, spring
# Topic #33: second, high, middle, east, markets, food, stocks, expensive, decade, wealth
# Topic #34: thing, way, same, life, idea, friend, sort, great, wrong, words
# Topic #35: russia, military, war, defense, russian, threat, effort, weapons, allies, press
# Topic #36: day, next, history, to, the, example, in, daily, rest, piece
# Topic #37: car, driving, cars, self driving, vehicles, cities, road, driving cars, passengers, roads
# Topic #38: francisco, san francisco, san, store, similar, style, fast, are, creative, brand
# Topic #39: third, hundreds, dollars, instagram, community, long time, actual, significant, cost, previous
# Topic #40: democrats, congress, senate, presidential, republicans, committee, republican, sen, senator, congressional
# Topic #41: air, change, natural, square, ground, energy, foundation, property, parts, village
# Topic #42: team, center, efforts, investigation, michael, general, local, letter, vice, robert
# Topic #43: case, it, share, click, deal, chairman, worth, opportunity, strong, close
# Topic #44: recognition, amazon, cloud, facial, facial recognition, microsoft, cloud computing, computing, recognition technology, services
# Topic #45: men, family, show, talk, french, husband, ms, scene, film, magazine
# Topic #46: city, night, name, weeks, black, streets, year old, front, face, thousands
# Topic #47: law, police, violent, violence, officers, authorities, criminal, legal, june, journalists
# Topic #48: big, terms, which, short, huge, interest, enough, scale, term, generation
# Topic #49: long, others, hard, small, able, past, clear, free, large, don

# %% [markdown]
# ## 3. Verifying the topic model   <a name="verifying_the_topic_model"></a>

# %% [markdown]
# The Intertopic Distance Map shows all topics that are in the topic model, their sizes and their proximity to other topics (whether they appear in the same documents)

# %%
list_topics_to_remove = []
intertopic_distance_map(df_with_topics, topics, list_topics_to_remove)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="88ea75fb-fa69-453f-a6c8-117bb7373d9a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88ea75fb-fa69-453f-a6c8-117bb7373d9a")) {                    Plotly.newPlot(                        "88ea75fb-fa69-453f-a6c8-117bb7373d9a",                        [{"customdata":[[0,"justice | fair | office | post | court",782.0],[1,"privacy | personal data | data privacy | privacy concerns | data",651.0],[2,"subsidiary news | hill street | contents site | corp subsidiary | fax contents",244.0],[3,"environmental | sustainable | iot | internet things | sustainability",1257.0],[4,"transparency | transparent | silicon valley | silicon | valley",803.0],[5,"accountability | accountable | enforcement | law enforcement | groups",680.0],[6,"autonomy | tear gas | kong police | carrie lam | demonstrators",235.0],[7,"political | democracy | democratic | election | human rights",808.0],[8,"learning | machine | machine learning | reliability | robust",2959.0],[9,"much | course | few | right | first",707.0],[10,"welfare | well being | care | health | well",808.0],[11,"everyone | real | home | book | sense",684.0],[12,"last | year | york | new york | government",2789.0],[13,"foreign | china | trade | leader | hong",803.0],[14,"business | money | market | investors | capital",1566.0],[15,"american | america | report | americans | private",1079.0],[16,"service | favorite | jeff | blog | numbers",1214.0],[17,"lives | questions | likely | decisions | problems",815.0],[18,"public | force | program | risk | safety",911.0],[19,"company | tech | companies | tech companies | industry",1578.0],[20,"economic | european | west | central | europe",1055.0],[21,"something | lot | kind | ve | re",738.0],[22,"google | app | users | online | apple",872.0],[23,"chinese | reuters | monday | reporting | friday",1131.0],[24,"trump | president | house | white house | administration",936.0],[25,"former | state | bill | john | morning",931.0],[26,"product | start | startups | co | price",1065.0],[27,"facebook | social media | media | social | zuckerberg",562.0],[28,"old | days | story | school | back",877.0],[29,"so | so called | called | important | sexual",1064.0],[30,"university | computer | professor | science | humans",808.0],[31,"answer | editor | son | decades | late",1080.0],[32,"times | many | party | power | line",1025.0],[33,"second | high | middle | east | markets",1056.0],[34,"thing | way | same | life | idea",778.0],[35,"russia | military | war | defense | russian",736.0],[36,"day | next | history | to | the",958.0],[37,"car | driving | cars | self driving | vehicles",990.0],[38,"francisco | san francisco | san | store | similar",884.0],[39,"third | hundreds | dollars | instagram | community",801.0],[40,"democrats | congress | senate | presidential | republicans",480.0],[41,"air | change | natural | square | ground",495.0],[42,"team | center | efforts | investigation | michael",940.0],[43,"case | it | share | click | deal",965.0],[44,"recognition | amazon | cloud | facial | facial recognition",1065.0],[45,"men | family | show | talk | french",950.0],[46,"city | night | name | weeks | black",755.0],[47,"law | police | violent | violence | officers",911.0],[48,"big | terms | which | short | huge",686.0],[49,"long | others | hard | small | able",669.0]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[782.0,651.0,244.0,1257.0,803.0,680.0,235.0,808.0,2959.0,707.0,808.0,684.0,2789.0,803.0,1566.0,1079.0,1214.0,815.0,911.0,1578.0,1055.0,738.0,872.0,1131.0,936.0,931.0,1065.0,562.0,877.0,1064.0,808.0,1080.0,1025.0,1056.0,778.0,736.0,958.0,990.0,884.0,801.0,480.0,495.0,940.0,965.0,1065.0,9 ...

# %% [markdown]
# The list hereunder shows the different topics in the topic model, and the weights attributed to words in each topic.

# %%
for topic, words in topics_weights.items():
  print(str(topic)+": "+str(words))
# Out:
# Topic #0# (Justice and Fairness): {'justice': 0.418, 'fair': 0.254, 'office': 0.165, 'post': 0.148, 'court': 0.137, 'politics': 0.132, 'sure': 0.114, 'today': 0.112, 'look': 0.112, 'california': 0.094}
# Topic #1# (Privacy): {'privacy': 2.063, 'personal data': 0.232, 'data privacy': 0.217, 'privacy concerns': 0.112, 'data': 0.076, 'surveillance': 0.059, 'data protection': 0.058, 'security privacy': 0.047, 'protection': 0.042, 'consent': 0.04}
# Topic #2# (Cyber-security): {'subsidiary news': 0.408, 'hill street': 0.408, 'contents site': 0.408, 'corp subsidiary': 0.408, 'fax contents': 0.408, 'news communications': 0.408, 'nw': 0.408, 'nw suite': 0.408, 'publishing corp': 0.408, 'dc 202': 0.408}
# Topic #3# (Environmnental Sustainability): {'environmental': 0.508, 'sustainable': 0.316, 'iot': 0.145, 'internet things': 0.131, 'sustainability': 0.125, 'things iot': 0.124, 'renewable': 0.094, 'sustainable development': 0.072, 'smart': 0.053, 'management': 0.045}
# Topic #4# (Transparency): {'transparency': 0.664, 'transparent': 0.385, 'silicon valley': 0.264, 'silicon': 0.238, 'valley': 0.236, 'opaque': 0.134, 'explainable': 0.09, 'explainability': 0.078, 'practices': 0.065, 'regulation': 0.04}
# Topic #5# (Accountability): {'accountability': 0.446, 'accountable': 0.343, 'enforcement': 0.163, 'law enforcement': 0.151, 'groups': 0.111, 'crime': 0.076, 'agencies': 0.07, 'nbc': 0.065, 'interference': 0.06, 'testimony': 0.059}
# Topic #6# (Autonomy): {'autonomy': 1.228, 'tear gas': 0.077, 'kong police': 0.074, 'carrie lam': 0.073, 'demonstrators': 0.069, 'tear': 0.069, 'lam': 0.062, 'country systems': 0.061, 'protesters hong': 0.059, 'extradition bill': 0.057}
# Topic #7# (Democracy): {'political': 1.054, 'democracy': 0.64, 'democratic': 0.619, 'election': 0.19, 'human rights': 0.184, 'campaign': 0.184, 'elections': 0.119, 'voters': 0.117, 'anti': 0.105, 'vote': 0.1}
# Topic #8# (Reliability): {'learning': 0.246, 'machine': 0.217, 'machine learning': 0.209, 'reliability': 0.164, 'robust': 0.088, 'algorithm': 0.071, 'deep learning': 0.071, 'neural': 0.068, 'robustness': 0.061, 'algorithms': 0.058}
# Topic #9# (Trust): {'much': 0.246, 'course': 0.231, 'few': 0.208, 'right': 0.204, 'first': 0.193, 'point': 0.189, 'anything': 0.184, 'little': 0.181, 'person': 0.173, 'someone': 0.172}
# Topic #10# (Well-being): {'welfare': 0.293, 'well being': 0.214, 'care': 0.151, 'health': 0.146, 'well': 0.103, 'health care': 0.093, 'class': 0.092, 'patients': 0.07, 'medical': 0.068, 'being': 0.066}
# Topic #11# (Inclusiveness): {'everyone': 0.187, 'real': 0.157, 'home': 0.146, 'book': 0.146, 'sense': 0.142, 'only': 0.142, 'diversity': 0.138, 'word': 0.137, 'young': 0.137, 'mind': 0.132}
# Topic #12#: {'last': 0.356, 'year': 0.355, 'york': 0.217, 'new york': 0.213, 'government': 0.209, 'country': 0.203, 'week': 0.201, 'news': 0.2, 'years': 0.192, 'publishing': 0.191}
# Topic #13#: {'foreign': 0.209, 'china': 0.18, 'trade': 0.165, 'leader': 0.148, 'hong': 0.148, 'hong kong': 0.143, 'kong': 0.143, 'protests': 0.13, 'xi': 0.12, 'beijing': 0.12}
# Topic #14#: {'business': 0.214, 'money': 0.2, 'market': 0.196, 'investors': 0.136, 'capital': 0.132, 'businesses': 0.128, 'firm': 0.126, 'investment': 0.124, 'founder': 0.107, 'fund': 0.105}
# Topic #15#: {'american': 0.228, 'america': 0.202, 'report': 0.16, 'americans': 0.148, 'private': 0.135, 'nation': 0.135, 'issue': 0.133, 'major': 0.107, 'laws': 0.104, 'policies': 0.101}
# Topic #16#: {'service': 0.092, 'favorite': 0.082, 'jeff': 0.077, 'blog': 0.07, 'numbers': 0.07, 'drug': 0.069, 'specific': 0.06, 'potential': 0.06, 'internal': 0.06, 'bezos': 0.059}
# Topic #17#: {'lives': 0.111, 'questions': 0.11, 'likely': 0.101, 'decisions': 0.091, 'problems': 0.086, 'think': 0.078, 'negative': 0.07, 'responsible': 0.069, 'positive': 0.065, 'language': 0.065}
# Topic #18#: {'public': 0.22, 'force': 0.105, 'program': 0.098, 'risk': 0.081, 'safety': 0.077, 'miles': 0.071, 'climate': 0.066, 'conference': 0.062, 'system': 0.058, 'residents': 0.055}
# Topic #19#: {'company': 0.336, 'tech': 0.312, 'companies': 0.309, 'tech companies': 0.168, 'industry': 0.152, 'employees': 0.136, 'products': 0.122, 'technology': 0.118, 'ceo': 0.113, 'software': 0.108}
# Topic #20#: {'economic': 0.121, 'european': 0.102, 'west': 0.089, 'central': 0.084, 'europe': 0.082, 'step': 0.08, 'region': 0.075, 'sign': 0.073, 'western': 0.071, 'annual': 0.067}
# Topic #21#: {'something': 0.227, 'lot': 0.209, 'kind': 0.187, 've': 0.184, 're': 0.182, 'bad': 0.173, 'everything': 0.173, 'isn': 0.164, 'good': 0.161, 'work': 0.157}
# Topic #22#: {'google': 0.24, 'app': 0.166, 'users': 0.159, 'online': 0.145, 'apple': 0.123, 'web': 0.117, 'video': 0.106, 'digital': 0.101, 'facebook google': 0.096, 'advertising': 0.092}
# Topic #23#: {'chinese': 0.162, 'reuters': 0.158, 'monday': 0.133, 'reporting': 0.1, 'friday': 0.092, 'statement': 0.089, 'additional': 0.085, 'chinese government': 0.083, 'tuesday': 0.076, 'additional reporting': 0.069}
# Topic #24#: {'trump': 0.463, 'president': 0.372, 'house': 0.306, 'white house': 0.265, 'administration': 0.253, 'washington': 0.237, 'united': 0.22, 'states': 0.216, 'united states': 0.203, 'white': 0.2}
# Topic #25#: {'former': 0.212, 'state': 0.192, 'bill': 0.172, 'john': 0.155, 'morning': 0.152, 'civil': 0.143, 'meeting': 0.105, 'wednesday': 0.101, 'opposition': 0.091, 'activists': 0.091}
# Topic #26#: {'product': 0.11, 'start': 0.086, 'startups': 0.085, 'co': 0.078, 'price': 0.078, 'founders': 0.076, 'startup': 0.073, 'brands': 0.064, 'co founder': 0.064, 'business model': 0.061}
# Topic #27#: {'facebook': 0.306, 'social media': 0.28, 'media': 0.27, 'social': 0.203, 'zuckerberg': 0.193, 'twitter': 0.162, 'content': 0.162, 'mark': 0.161, 'platforms': 0.151, 'platform': 0.12}
# Topic #28#: {'old': 0.187, 'days': 0.176, 'story': 0.172, 'school': 0.148, 'back': 0.141, 'children': 0.135, 'full': 0.119, 'phone': 0.111, 'summer': 0.11, 'call': 0.104}
# Topic #29#: {'so': 0.204, 'so called': 0.15, 'called': 0.15, 'important': 0.097, 'sexual': 0.073, 'dark': 0.071, 'order': 0.07, 'audience': 0.069, 'beliefs': 0.064, 'abuse': 0.058}
# Topic #30#: {'university': 0.148, 'computer': 0.116, 'professor': 0.104, 'science': 0.103, 'humans': 0.095, 'stanford': 0.081, 'computer science': 0.081, 'human': 0.074, 'berkeley': 0.069, 'machines': 0.058}
# Topic #31#: {'answer': 0.112, 'editor': 0.111, 'son': 0.099, 'decades': 0.094, 'late': 0.091, 'age': 0.09, 'fear': 0.084, 'century': 0.082, 'feel': 0.073, 'reality': 0.072}
# Topic #32#: {'times': 0.187, 'many': 0.181, 'party': 0.15, 'power': 0.14, 'line': 0.137, 'movement': 0.114, 'up': 0.103, 'email': 0.102, 'page': 0.095, 'spring': 0.092}
# Topic #33#: {'second': 0.144, 'high': 0.142, 'middle': 0.122, 'east': 0.103, 'markets': 0.08, 'food': 0.071, 'stocks': 0.063, 'expensive': 0.062, 'decade': 0.061, 'wealth': 0.058}
# Topic #34#: {'thing': 0.228, 'way': 0.213, 'same': 0.191, 'life': 0.184, 'idea': 0.173, 'friend': 0.154, 'sort': 0.154, 'great': 0.147, 'wrong': 0.125, 'words': 0.117}
# Topic #35#: {'russia': 0.174, 'military': 0.167, 'war': 0.164, 'defense': 0.156, 'russian': 0.125, 'threat': 0.105, 'effort': 0.099, 'weapons': 0.095, 'allies': 0.093, 'press': 0.093}
# Topic #36#: {'day': 0.184, 'next': 0.173, 'history': 0.146, 'to': 0.119, 'the': 0.105, 'example': 0.104, 'in': 0.102, 'daily': 0.1, 'rest': 0.091, 'piece': 0.09}
# Topic #37#: {'car': 0.166, 'driving': 0.129, 'cars': 0.129, 'self driving': 0.124, 'vehicles': 0.103, 'cities': 0.088, 'road': 0.081, 'driving cars': 0.072, 'passengers': 0.056, 'roads': 0.055}
# Topic #38#: {'francisco': 0.113, 'san francisco': 0.11, 'san': 0.11, 'store': 0.101, 'similar': 0.078, 'style': 0.071, 'fast': 0.065, 'are': 0.062, 'creative': 0.061, 'brand': 0.06}
# Topic #39#: {'third': 0.115, 'hundreds': 0.096, 'dollars': 0.094, 'instagram': 0.085, 'community': 0.079, 'long time': 0.072, 'actual': 0.071, 'significant': 0.063, 'cost': 0.06, 'previous': 0.059}
# Topic #40#: {'democrats': 0.231, 'congress': 0.211, 'senate': 0.195, 'presidential': 0.18, 'republicans': 0.17, 'committee': 0.162, 'republican': 0.15, 'sen': 0.132, 'senator': 0.123, 'congressional': 0.117}
# Topic #41#: {'air': 0.123, 'change': 0.091, 'natural': 0.089, 'square': 0.081, 'ground': 0.067, 'energy': 0.062, 'foundation': 0.06, 'property': 0.055, 'parts': 0.054, 'village': 0.053}
# Topic #42#: {'team': 0.166, 'center': 0.108, 'efforts': 0.106, 'investigation': 0.105, 'michael': 0.105, 'general': 0.103, 'local': 0.096, 'letter': 0.096, 'vice': 0.096, 'robert': 0.095}
# Topic #43#: {'case': 0.145, 'it': 0.108, 'share': 0.108, 'click': 0.107, 'deal': 0.107, 'chairman': 0.093, 'worth': 0.092, 'opportunity': 0.089, 'strong': 0.08, 'close': 0.08}
# Topic #44#: {'recognition': 0.175, 'amazon': 0.156, 'cloud': 0.154, 'facial': 0.14, 'facial recognition': 0.13, 'microsoft': 0.123, 'cloud computing': 0.101, 'computing': 0.096, 'recognition technology': 0.088, 'services': 0.086}
# Topic #45#: {'men': 0.156, 'family': 0.155, 'show': 0.128, 'talk': 0.091, 'french': 0.086, 'husband': 0.079, 'ms': 0.076, 'scene': 0.074, 'film': 0.074, 'magazine': 0.073}
# Topic #46#: {'city': 0.213, 'night': 0.169, 'name': 0.137, 'weeks': 0.133, 'black': 0.129, 'streets': 0.125, 'year old': 0.1, 'front': 0.099, 'face': 0.091, 'thousands': 0.085}
# Topic #47#: {'law': 0.226, 'police': 0.168, 'violent': 0.123, 'violence': 0.112, 'officers': 0.106, 'authorities': 0.103, 'criminal': 0.093, 'legal': 0.09, 'june': 0.089, 'journalists': 0.084}
# Topic #48#: {'big': 0.121, 'terms': 0.094, 'which': 0.093, 'short': 0.091, 'huge': 0.088, 'interest': 0.083, 'enough': 0.077, 'scale': 0.075, 'term': 0.075, 'generation': 0.069}
# Topic #49#: {'long': 0.167, 'others': 0.153, 'hard': 0.147, 'small': 0.137, 'able': 0.136, 'past': 0.123, 'clear': 0.123, 'free': 0.115, 'large': 0.113, 'don': 0.113}

# %% [markdown]
# We can also build an Intertopic Distance Map for articles on specific values

# %%
list_topics_to_remove = []

def plot_top_topics_on_values(selected_value):
  selected_value_int = list(dict_anchor_words.keys()).index(selected_value)
  df_to_evaluate = df_with_topics
  df_to_evaluate = df_to_evaluate.loc[(df_to_evaluate[selected_value_int] == 1)]
  list_topics_to_remove.append(selected_value_int)
  return(intertopic_distance_map(df_to_evaluate, topics, list_topics_to_remove))

my_interact_manual = interact_manual.options(manual_name="Plot topics on value")
my_interact_manual(plot_top_topics_on_values, selected_value=[*dict_anchor_words])
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_top_topics_on_values(selected_value)>

# %% [markdown]
# And next we can sample a number of documents on specific values and related topics

# %%
def plot_print_sample_articles_topic(selected_value, selected_topic, show_full_text, window, size_sample):
    show_extracts = True # True, False
    df_to_evaluate = df_with_topics
    if selected_topic == "":
      selected_topic = 0
    df_to_evaluate = df_to_evaluate.loc[(df_to_evaluate[int(selected_topic)] == 1)]
    print("Keywords related to selected topic: "+str(topics[int(selected_topic)]))
    print_sample_articles_topic(df_to_evaluate, dict_anchor_words, topics, selected_value, size_sample, window, show_extracts, show_full_text)

my_interact_manual = interact_manual.options(manual_name="Plot articles on value")
my_interact_manual(plot_print_sample_articles_topic, selected_value=[*dict_anchor_words], selected_topic=widgets.Text(), size_sample =(5,20, 5), window =(5,100, 5), show_full_text = widgets.Checkbox(value=False))
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_print_sample_articles_topic(selected_value, selected_topic, show_full_text, window, size_sample)>

# %% [markdown]
# ## 4. Values in different realms <a name="values_in_different_realms"></a>

# %% [markdown]
# ValueMonitor can be used to evaluate which values different societal groups tend to discuss.

# %%
def plot_values_in_different_groups(selected_dataset):
    values_in_different_groups(df_with_topics, dict_anchor_words, selected_dataset)

interact(plot_values_in_different_groups, selected_dataset = df_with_topics.groupby(['dataset']).size().index.tolist())
# Out:
# interactive(children=(Dropdown(description='selected_dataset', options=('ETHICS', 'NEWS', 'TECH'), value='ETHI…
# <function __main__.plot_values_in_different_groups(selected_dataset)>

# %%
list_topics_to_remove = []

def plot_top_topics_on_values(selected_value, selected_dataset):
  selected_value_int = list(dict_anchor_words.keys()).index(selected_value)
  df_to_evaluate = df_with_topics
  df_to_evaluate = df_to_evaluate[df_to_evaluate['dataset'] == selected_dataset]
  df_to_evaluate = df_to_evaluate.loc[(df_to_evaluate[selected_value_int] == 1)]
  list_topics_to_remove.append(selected_value_int)
  return(intertopic_distance_map(df_to_evaluate, topics, list_topics_to_remove))

my_interact_manual = interact_manual.options(manual_name="Plot topics in realm")
my_interact_manual(plot_top_topics_on_values, selected_value=[*dict_anchor_words], selected_dataset = df_with_topics.groupby(['dataset']).size().index.tolist())
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_top_topics_on_values(selected_value, selected_dataset)>

# %%
def plot_print_sample_articles_topic(selected_value, selected_dataset, selected_topic, show_full_text, window, size_sample):
    show_extracts = True # True, False
    df_to_evaluate = df_with_topics
    if selected_topic == "":
      selected_topic = 0
    df_to_evaluate = df_to_evaluate[df_to_evaluate['dataset'] == selected_dataset]
    df_to_evaluate = df_to_evaluate.loc[(df_to_evaluate[int(selected_topic)] == 1)]
    print("Keywords related to selected topic: "+str(topics[int(selected_topic)]))
    print_sample_articles_topic(df_to_evaluate, dict_anchor_words, topics, selected_value, size_sample, window, show_extracts, show_full_text)

my_interact_manual = interact_manual.options(manual_name="Plot articles on value")
my_interact_manual(plot_print_sample_articles_topic, selected_value=[*dict_anchor_words], selected_dataset = df_with_topics.groupby(['dataset']).size().index.tolist(), selected_topic=widgets.Text(), size_sample =(5,20, 5), window =(5,100, 5), show_full_text = widgets.Checkbox(value=False))
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_print_sample_articles_topic(selected_value, selected_dataset, selected_topic, show_full_text, window, size_sample)>

# %% [markdown]
# ## 5. Values over time <a name="values_over_time"></a>

# %% [markdown]
# The occurence of values can be traced over time.

# %%
def plot_create_vis_values_over_time (selected_dataset, resampling, starttime, endtime, smoothing, max_value_y):
    values_to_include_in_visualisation = []   
    resampling_dict = {"Year": "Y", "Month": "M", "Day": "D"}
    resampling = resampling_dict[resampling]
    selected_df_with_topics = df_with_topics
    if selected_dataset != "All datasets":
      selected_df_with_topics = selected_df_with_topics[selected_df_with_topics['dataset'] == selected_dataset]
    selected_df_with_topics = selected_df_with_topics.loc[(selected_df_with_topics['date'] >= dateutil.parser.parse(str(starttime))) & (selected_df_with_topics['date'] <= dateutil.parser.parse(str(endtime)))]

    create_vis_values_over_time(selected_df_with_topics, dict_anchor_words, resampling, values_to_include_in_visualisation, smoothing, max_value_y)  

my_interact_manual = interact_manual.options(manual_name="Plot values over time")
my_interact_manual(plot_create_vis_values_over_time, selected_dataset = ["All datasets"] + df_with_topics.groupby(['dataset']).size().index.tolist(), starttime =(1960,2022, 2), endtime =(1965,2022, 2), smoothing = (0.25,3, 0.25), max_value_y = (5,100, 5), resampling = ["Year", "Month", "Day"])
# Out:
# interactive(children=(Dropdown(description='selected_dataset', options=('All datasets', 'ETHICS', 'NEWS', 'TEC…
# <function __main__.plot_create_vis_values_over_time(selected_dataset, resampling, starttime, endtime, smoothing, max_value_y)>

# %% [markdown]
# We can also observe how words used to discuss a value have changed over time

# %%
def plot_words_over_time (selected_value, selected_dataset, starttime, endtime, smoothing, max_value_y, resampling):
    list_words = []
    selected_df_with_topics = df_with_topics
    if selected_dataset != "All datasets":
      selected_df_with_topics = selected_df_with_topics.loc[(selected_df_with_topics["dataset"] == selected_dataset)]
    selected_df_with_topics = selected_df_with_topics.loc[(selected_df_with_topics['date'] >= dateutil.parser.parse(str(starttime))) & (selected_df_with_topics['date'] <= dateutil.parser.parse(str(endtime)))]
    top_words = 10
    list_words = topics[selected_value][:top_words]
    resampling_dict = {"Year": "Y", "Month": "M", "Day": "D"}
    selected_value_int = list(dict_anchor_words.keys()).index(selected_value)
    inspect_words_over_time(df_with_topics = selected_df_with_topics, topic_to_evaluate = selected_value_int, list_words = list_words, resampling = resampling_dict[resampling], smoothing = smoothing, max_value_y = max_value_y)

my_interact_manual = interact_manual.options(manual_name="Plot words over time")
my_interact_manual(plot_words_over_time, selected_value=[*dict_anchor_words], selected_dataset=["All datasets"] + df_with_topics.groupby(['dataset']).size().index.tolist(), starttime =(1960,2022, 2), endtime =(1965,2022, 2), smoothing = (0.1,3, 0.25), max_value_y = (5,100, 5), resampling = ["Year", "Month", "Day"])
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_words_over_time(selected_value, selected_dataset, starttime, endtime, smoothing, max_value_y, resampling)>

# %%
topics_to_remove_int = []

def plot_top_topics_over_time(selected_value, selected_dataset, starttime, endtime, top_topics_to_show, smoothing, max_value_y, resampling):
  resampling_dict = {"Year": "Y", "Month": "M", "Day": "D"}
  resampling = resampling_dict[resampling]
  df_to_evaluate = df_with_topics
  if selected_dataset != "All datasets":
    df_to_evaluate = df_to_evaluate.loc[(df_to_evaluate["dataset"] == selected_dataset)]
  df_to_evaluate = df_to_evaluate.loc[(df_to_evaluate['date'] >= dateutil.parser.parse(str(starttime))) & (df_to_evaluate['date'] <= dateutil.parser.parse(str(endtime)))]
  top_topics_on_values_over_time(df_to_evaluate, selected_value, dict_anchor_words, topics_weights, top_topics_to_show, topics_to_remove_int, smoothing, max_value_y, resampling)

my_interact_manual = interact_manual.options(manual_name="Plot related topics over time")
my_interact_manual(plot_top_topics_over_time, top_topics_to_show = (3, 25, 1), selected_value=[*dict_anchor_words], selected_dataset = ["All datasets"] + df_with_topics.groupby(['dataset']).size().index.tolist(), starttime =(1960,2022, 2), endtime =(1965,2022, 2), smoothing = (0.25,3, 0.25), max_value_y = (5,100, 5), resampling = ["Year", "Month", "Day"])
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_top_topics_over_time(selected_value, selected_dataset, starttime, endtime, top_topics_to_show, smoothing, max_value_y, resampling)>

# %%
def plot_print_sample_articles_topic(selected_value, selected_dataset, selected_topic, starttime, endtime, show_full_text, window, size_sample):
    show_extracts = True # True, False
    '''--------------------------------------------------------------------------''' 
    selected_dataframe = df_with_topics
    if selected_dataset != "All datasets":
      selected_dataframe = selected_dataframe.loc[(selected_dataset["dataset"] == selected_dataset)]
    selected_dataframe = selected_dataframe.loc[(selected_dataframe['date'] >= dateutil.parser.parse(str(starttime))) & (selected_dataframe['date'] <= dateutil.parser.parse(str(endtime)))]
    if selected_topic == "":
      selected_topic = 0
    selected_dataframe = selected_dataframe[selected_dataframe[int(selected_topic)] == 1]
    print("Keywords related to selected topic: "+str(topics[int(selected_topic)]))
    print_sample_articles_topic(selected_dataframe, dict_anchor_words, topics, selected_value, size_sample, window, show_extracts, show_full_text)

my_interact_manual = interact_manual.options(manual_name="Plot articles on topic")
my_interact_manual(plot_print_sample_articles_topic, selected_value=[*dict_anchor_words], selected_dataset = ["All datasets"] + df_with_topics.groupby(['dataset']).size().index.tolist(), starttime =(1960,2022, 2), endtime =(1965,2022, 2), selected_topic=widgets.Text(), size_sample =(5,20, 5), window =(5,100, 5), show_full_text = widgets.Checkbox(value=False))
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_print_sample_articles_topic(selected_value, selected_dataset, selected_topic, starttime, endtime, show_full_text, window, size_sample)>

# %% [markdown]
# ## 6. Gap assessment <a name="gap_assessment"></a>

# %% [markdown]
# It takes time before a good topic model is build in which topics adequately represent values. The code in the next cell can be used to import an existing topic model.

# %%
def plot_values_in_different_datasets():
  selected_df = df_with_topics
  values_in_different_datasets(selected_df, dict_anchor_words)

interact(plot_values_in_different_datasets)
# Out:
# interactive(children=(Output(),), _dom_classes=('widget-interact',))
# <function __main__.plot_values_in_different_datasets()>

# %%
list_topics_to_remove = []

def plot_top_topics_on_values(selected_value, selected_dataset):
  selected_value_int = list(dict_anchor_words.keys()).index(selected_value)
  df_to_evaluate = df_with_topics
  df_to_evaluate = df_to_evaluate[df_to_evaluate['dataset'] == selected_dataset]
  df_to_evaluate = df_to_evaluate.loc[(df_to_evaluate[selected_value_int] == 1)]
  list_topics_to_remove.append(selected_value_int)
  return(intertopic_distance_map(df_to_evaluate, topics, list_topics_to_remove))

my_interact_manual = interact_manual.options(manual_name="Plot topics in realm")
my_interact_manual(plot_top_topics_on_values, selected_value=[*dict_anchor_words], selected_dataset = df_with_topics.groupby(['dataset']).size().index.tolist())
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_top_topics_on_values(selected_value, selected_dataset)>

# %%
def plot_print_sample_articles_topic(selected_value, selected_dataset, show_full_text, window, size_sample):
    show_extracts = True # True, False
    '''--------------------------------------------------------------------------''' 
    selected_dataframe = df_with_topics
    if selected_dataset != "All datasets":
      selected_dataframe = selected_dataframe.loc[(selected_dataset["dataset"] == selected_dataset)]
    print_sample_articles_topic(selected_dataframe, dict_anchor_words, topics, selected_value, size_sample, window, show_extracts, show_full_text)

my_interact_manual = interact_manual.options(manual_name="Plot articles on value")
my_interact_manual(plot_print_sample_articles_topic, selected_value=[*dict_anchor_words], selected_dataset = ["All datasets"] + df_with_topics.groupby(['dataset']).size().index.tolist(), size_sample =(5,20, 5), window =(5,100, 5), show_full_text = widgets.Checkbox(value=False))
# Out:
# interactive(children=(Dropdown(description='selected_value', options=('Justice and Fairness', 'Privacy', 'Cybe…
# <function __main__.plot_print_sample_articles_topic(selected_value, selected_dataset, show_full_text, window, size_sample)>
